# %% [markdown]
# ![title](https://www.kolonbenit.com/common/images/logo.gif)
#
# # Kolon Benit BigData Analytics Team
# --------------------------------------
# ## SAS CI 360 API  Programming, 2019.08.13
# ### Example00 - How to Get Discovery Data of SAS CI 360
# --------------------------------------
# Austin Rho (Shin Seok),
# - contact : ssrho@kolon.com, injoyer@yonsei.ac.kr

# %%
# Sorry!!! On Editing Now!!!

# %%
 
import gzip

# Use open method.
with gzip.open("C:\\Project\\CI_Data\\0805\\GOAL_DETAILS_05.gz", "rb") as f:
    # Read in string.
    
    while True:
        line = f.readline()
        if not line: break
        print(line.decode('utf8').strip().split('\x01') )
        print(len(line))
    
    #print(line)
# Out:
# ['주문완료', '주문', '', '2019-08-05 05:57:44.584', '2019-08-05 14:57:44.584', '54042675217752072769643627082000', '48707644636991237513279617502', '6644030191135677271727607240', 'c0f8f90f-78c1-3fe2-9cf4-93510786ac77', '2019-08-05 08:39:28.25']
# 221
# ['주문완료', '주문', '', '2019-08-05 05:52:30.189', '2019-08-05 14:52:30.189', '53094005123835039496072826273000', '32734128330654888459569198476', '24361511555027659253834989979', 'ea37c384-3abf-32d8-8cb1-23479f08e465', '2019-08-05 08:39:28.25']
# 222

# %%
import requests

API_HOST = 'https://xxxxxxxervice-apn-prod.ci360.sas.com/marketingGateway/discoverService/dataDownload/eventData/detail/partitionedData?dataRangeStartTimeStamp=2019-08-05T00:00:00.000Z&dataRangeEndTimeStamp=2019-08-06T23:59:59.999Z'
APP_KEY = 'Bearer  xxxxxxhbGciOiJIUzI1NiJ9.eyJjbGllbnRJRCI6IjY0OTE5Mjg0Y2IwMDAxMGE1NjJmM2ViZCJ9.rSWQ1MwMngIYqEBhHFCrAvoq-lujMOrMee2WBTQyfWU'
headers = {'Authorization': APP_KEY}

def req(path, query, method, data={}):
    
    url = API_HOST + path
    print('HTTP Method: %s' % method)
    print('Request URL: %s' % url)
    print('Headers: %s' % headers)
    print('QueryString: %s' % query)
    
    if method == 'GET':
        return requests.get(url, headers=headers)
    else:
        return requests.post(url, headers=headers, data=data)

res = req('', '', 'GET')

print("response status:\n%d" % res.status_code)
print("response info:\n%s" % res.headers)
print("response body:\n%s" % res.text)
# Out:
# HTTP Method: GET
# Request URL: https://xxxxxxxxxxxxxxapn-prod.ci360.sas.com/marketingGateway/discoverService/dataDownload/eventData/detail/partitionedData?dataRangeStartTimeStamp=2019-08-05T00:00:00.000Z&dataRangeEndTimeStamp=2019-08-06T23:59:59.999Z
# Headers: {'Authorization': 'Bearer  eyJ0eXAiOxxxxxxxxxxxGllbnRJRCI6IjY0OTE5Mjg0Y2IwMDAxMGE1NjJmM2ViZCJ9.rSWQ1MwMngIYqEBhHFCrAvoq-lujMOrMee2WBTQyfWU'}
# QueryString:
# response status:
# 200
# response info:
# {'Date': 'Tue, 13 Aug 2019 00:42:58 GMT', 'Content-Type': 'application/vnd.sas.collection+json;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Amzn-Trace-Id': 'Root=1-5d520790-d9c78af29f81ed24d1e10e72;', 'X-Application-Context': 'application', 'Location': '/', 'Cache-Control': 'must-revalidate,no-cache,no-store'}
# response body:
# ...
